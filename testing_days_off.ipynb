# %%
# import numpy as np
# import matplotlib.pyplot as plt
from model import *

# %%
days_on_list = [21,22,23,24,25,26,27,28]

for days_on in days_on_list:
    tt, yy = solve(days_on)

    var_names = ['E_2', 'P_4', 'FSH', 'LH']
    plot_four_variables(yy, var_names, tt, days_on = days_on)
    plot_four_variables_red(yy, var_names, tt, days_on = days_on)
# Out:
# e dose days on: 21
# p dose days on: 21
# e dose days on: 21
# p dose days on: 21
# e dose days on: 22
# p dose days on: 22
# e dose days on: 22
# p dose days on: 22
# e dose days on: 23
# p dose days on: 23
# e dose days on: 23
# p dose days on: 23
# e dose days on: 24
# p dose days on: 24
# e dose days on: 24
# p dose days on: 24
# e dose days on: 25
# p dose days on: 25
# e dose days on: 25
# p dose days on: 25
# e dose days on: 26
# p dose days on: 26
# e dose days on: 26
# p dose days on: 26
# e dose days on: 27
# p dose days on: 27
# e dose days on: 27
# p dose days on: 27
# e dose days on: 28
# p dose days on: 28
# e dose days on: 28
# p dose days on: 28
