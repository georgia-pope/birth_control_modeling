# %%
import numpy as np
from ddeint import ddeint
import matplotlib.pyplot as plt

# %%
from model import *

# %%
tt, yy = solve()

# %% [markdown]
# ## On/Off Low Dose Both

# %%
var_names = ['E_2', 'P_4', 'FSH', 'LH']
plot_four_variables(yy, var_names, tt)

# %%
var_names = ['LH', 'RcF', 'GrF', 'DomF']
plot_four_variables(yy, var_names, tt)

# %% [markdown]
# ## Low Dose Both

# %%
var_names = ['E_2', 'P_4', 'FSH', 'LH']
plot_four_variables(yy, var_names, tt)

# %%
var_names = ['LH', 'RcF', 'GrF', 'DomF']
plot_four_variables(yy, var_names, tt)

# %% [markdown]
# ## Normal Cycle

# %%
var_names = ['E_2', 'P_4', 'FSH', 'LH']
plot_four_variables(yy, var_names, tt)

# %%
var_names = ['LH', 'RcF', 'GrF', 'DomF']
plot_four_variables(yy, var_names, tt)

# %% [markdown]
# ## 14 day offset On/Off Low Dose Both

# %%
var_names = ['E_2', 'P_4', 'FSH', 'LH']
plot_four_variables(yy, var_names, tt)

# %%
var_names = ['LH', 'RcF', 'GrF', 'DomF']
plot_four_variables(yy, var_names, tt)

# %% [markdown]
# ## On/Off High Dose Both

# %%
var_names = ['E_2', 'P_4', 'FSH', 'LH']
plot_four_variables(yy, var_names, tt)

# %%
var_names = ['LH', 'RcF', 'GrF', 'DomF']
plot_four_variables(yy, var_names, tt)
